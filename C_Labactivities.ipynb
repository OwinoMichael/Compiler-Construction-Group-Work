# %% [markdown]
# <a href="https://colab.research.google.com/github/OwinoMichael/Compiler-Construction-Group-Work/blob/main/C_Labactivities.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **LAB 1**

# %% [markdown]
# COMPILER CONSTRUCTION GROUP MEMBERS
# 1. 106731-Raphael Oluoch
# 2. 100701-Kelong Zacharia
# 3. 120921-Owino Michael

# %% [markdown]
# # **INTRODUCTION**

# %% [markdown]
# **FLEX**
# Fast lexical analyzer generator is a computer program or a tool that's used to generate lexical analyzers such scanners or lexers. For its optimal functioning it is intergrated together with Berkely Yacc parser generator or the GNU Bison parser generator. Flex was initially written by Vern parkson in the language c around the year 1987.
#
# ![flex-fast-lexical-analyzer-generator-7-320.jpg](data:image/jpeg;base64,...)
#
# Sample code of flex.
# The code below replaces the the sequence of symbols in a text file {number number} to {"d" ws "d"}, and it calculates the number of replacements
#
# ![flex.png](data:image/png;base64,...)

# %% [markdown]
# ## **BISON**
# Bison is a parser generator that translates a grammatical description(Bison garmmer files), for an LALR(1) context-free grammar into a C program to parse that grammar. Bison parser is a bottom-up parser.
# Below is a bison diagram
# ![image.png](data:image/png;base64,...)
#
#
#
# It attempts to reduce the whole input to a single grouping whose symbol is the grammar's start-symbol via shifts and reductions.
# The layout of the Bison grammar file is:
#
# %{
# C declarations
# %}
#
# Bison declarations
#
# %%
#
#
# Grammar rules
#
#
# %%
#
# Additional C code
#
# Sample code oa Byson parser file.

# %% [markdown]
# # **LEX**
# Lex is a tool in lexical analysis phase to recognize tokens using regular expression. Lex is a program that generates lexical analyzer.
#
# ![lexy.png](data:image/png;base64,...)
#
#
# A Lex program is separated into three sections by %% delimiters. The formal of Lex source is as follows:
#
# { definitions }
# %%
#  { rules }
# %%
# { user subroutines }
#
# Sample code of Lex in C.
# A lex program to count the number of words
#
# ![xel.png](data:image/png;base64,...)

# %% [markdown]
# # **YACC**
# Yacc is a tool used to create a parser. It parses the stream of tokens from the Lex file and performs the semantic analysis. It translates a given Context-Free Grammar (CFG) specifications into a C implementation y.tab.c. This C program when compiled, yields an executable parser.
#
# ![yaccy.png](data:image/png;base64,...)
#
# A Yacc file is in many ways, similar to the Lex file.
#
# {declaration}
# %%
# {rules}
# %%
# {subroutines}
#
# Sample Code of Yacc in C.
# The yacc program generates that file from the yacc grammar file information.
#
# ![yacc.png](data:image/png;base64,...)

# %% [markdown]
# # **REFERENCES**
# Flex (Fast Lexical Analyzer Generator ) - GeeksforGeeks. (2022). Retrieved 12 September 2022, from https://www.geeksforgeeks.org/flex-fast-lexical-analyzer-generator/
#
# Bison in compiler construction. (2022). Retrieved 12 September 2022, from https://www.admb-project.org/tools/flex/compiler.pdf
#
# Bison Tutorial. (2022). Retrieved 12 September 2022, from http://alumni.cs.ucr.edu/~lgao/teaching/bison.html
#
# How to Build a C Compiler Using Lex and Yacc. Retrieved September 2022, from (https://https://medium.com/codex/building-a-c-compiler-using-lex-and-yacc-446262056aaa)
#
# Introduction to Yacc, retreived September 2022 from (https://https://www.geeksforgeeks.org/introduction-to-yacc/)
#
# Lex. Retrieved 12 Septemeber 2022 from (https://https://www.javatpoint.com/lex)

# %% [markdown]
# # LAB ACTIVITY **2**

# %% [markdown]
# Activity 2A

# %% [markdown]
# ![LAB 2A.jpg](data:image/jpeg;base64,...)
