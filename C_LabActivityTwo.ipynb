# %% [markdown]
# <a href="https://colab.research.google.com/github/OwinoMichael/Compiler-Construction-Group-Work/blob/main/C_LabActivityTwo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# COMPILER CONSTRUCTION GROUP MEMBERS
# 1. 106731-Raphael Oluoch
# 2. 100701-Kelong Zacharia
# 3. 120921-Owino Michael
# 4. 122287-Oduor Michael Owen

# %% [markdown]
# **NFA to DFA example 1**
# ![WhatsApp Image 2022-09-20 at 23.32.20.jpeg](data:image/jpeg;base64,...)
#
#
# ![WhatsApp Image 2022-09-20 at 23.32.21.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# **NFA to DFA example 2**
#
# ![WhatsApp Image 2022-09-20 at 23.32.21.jpeg](data:image/jpeg;base64,...)
#
# ![WhatsApp Image 2022-09-20 at 23.32.21.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # How to use flex when building a lexical analyzer

# %%
# %{
int count = 0;
%}

%%
[A-Z] {printf("%s capital letter\n", yytext);
       count++;}
.     {printf("%s not a capital letter\n", yytext);}
\n    {return 0;}
%%

int yywrap(){}
int main(){
yylex();
printf("\nNumber of Capital letters " 
      "in the given input - %d\n", count);
  
return 0;
}

# %% [markdown]
# How to use bison when building a lexical analyzer

# %% [markdown]
# ![Screenshot (116).png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot (115).png](data:image/png;base64,...)
